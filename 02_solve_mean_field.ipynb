# %%
import h5py

f = h5py.File('./tracesnaive.h5', 'r')

# %%
list(f.keys())
# Out:
# ['Dataset1']

# %%
dset = f['Dataset1']

# %%
dset.shape
# Out:
# (60001, 11)

# %%
import matplotlib.pyplot as plt
plt.plot(dset[:,10])

# %%
f.close()
